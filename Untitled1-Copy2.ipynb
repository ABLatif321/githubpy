# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
df = pd.read_csv('C:/Users/USER/Desktop/clusterexam/awsimp.csv')
df.head()
# Out:
#    239  885775393  base_link  81379.7890625  49918.66796875  \
# 0  239  889217394  base_link   81379.835938    49918.691406
# 1  239  890862394  base_link   81379.875000    49918.718750
# 2  239  893196394  base_link   81379.914062    49918.746094
# 3  239  922387395  base_link   81379.960938    49918.769531
# 4  239  924705395  base_link   81380.000000    49918.796875
#
#    41.23166275024414  0.002315291203558445  -0.0048871408216655254  \
# 0          41.232151              0.002394               -0.004840
# 1          41.232666              0.002467               -0.004789
# 2          41.233204              0.002537               -0.004734
# 3          41.233757              0.002604               -0.004676
# 4          41.234333              0.002672               -0.004613
#
#    0.272693932056427  0.9620856046676636
# 0           0.272746            0.962071
# 1           0.272792            0.962058
# 2           0.272837            0.962045
# ...

# %%
df['885775393'].head()
# Out:
# 0    889217394
# 1    890862394
# 2    893196394
# 3    922387395
# 4    924705395
# Name: 885775393, dtype: int64

# %%
df['81379.7890625'].head()
# Out:
# 0    81379.835938
# 1    81379.875000
# 2    81379.914062
# 3    81379.960938
# 4    81380.000000
# Name: 81379.7890625, dtype: float64

# %%
df['49918.66796875'].head()
# Out:
# 0    49918.691406
# 1    49918.718750
# 2    49918.746094
# 3    49918.769531
# 4    49918.796875
# Name: 49918.66796875, dtype: float64

# %%
df['41.23166275024414'].head()
# Out:
# 0    41.232151
# 1    41.232666
# 2    41.233204
# 3    41.233757
# 4    41.234333
# Name: 41.23166275024414, dtype: float64

# %%
df['0.002315291203558445'].head()
# Out:
# 0    0.002394
# 1    0.002467
# 2    0.002537
# 3    0.002604
# 4    0.002672
# Name: 0.002315291203558445, dtype: float64

# %%
df['-0.0048871408216655254'].head()
# Out:
# 0   -0.004840
# 1   -0.004789
# 2   -0.004734
# 3   -0.004676
# 4   -0.004613
# Name: -0.0048871408216655254, dtype: float64

# %%
df['0.272693932056427'].head()
# Out:
# 0    0.272746
# 1    0.272792
# 2    0.272837
# 3    0.272880
# 4    0.272923
# Name: 0.272693932056427, dtype: float64

# %%
df['0.9620856046676636'].head()
# Out:
# 0    0.962071
# 1    0.962058
# 2    0.962045
# 3    0.962033
# 4    0.962021
# Name: 0.9620856046676636, dtype: float64

# %%
v= np.array([df['81379.7890625'],df['49918.66796875'],df['41.23166275024414']])

# %%
#v1=np.transpose(v)

# %%
#def euler_to_Rot('c', 'b', 'a'):
    #Y = np.array([[cos(df['c']), 0, sin(df['c'])],
                  [0, 1, 0],
                  [-sin(df['c']), 0, cos(df['c'])]])
    #P = np.array([[1, 0, 0],
                  [0, cos(df['b']), -sin(df['b'])],
                  [0, sin(df['b']), cos(df['b'])]])
   # R = np.array([[cos(df['a']), -sin(df['a']), 0],
                  [sin(df['a']), cos(df['a']), 0],
                  [0, 0, 1]])
   # return np.dot(Y, np.dot(P, R))
# Out:
#   Cell In[125], line 3
#     [0, 1, 0],
#     ^
# IndentationError: unexpected indent

# %%
plt.scatter( df['885775393'], df['81379.7890625'],df['0.9620856046676636'])
plt.show()
